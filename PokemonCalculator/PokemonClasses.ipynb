# %% [markdown]
# Hello this is me practicing classes for the first time in python.

# %%
class Pokemon():
    Name = " "
    Type1 = " "
    Type2 = " "
    HP = 0
    Attack = 0
    Defense = 0
    Special = 0
    Speed = 0
    def __init__(self, Name, Type1, Type2, HP, Attack, Defense, Special, Speed):
        self.Name = Name
        self.Type1 = Type1
        self.Type2 = Type2
        self.HP = HP
        self.Attack = Attack
        self.Defense = Defense
        self.Special = Special
        self.Speed = Speed

# %%
p1 = Pokemon
p1.HP
# Out:
# 0

# %%
import csv

PokemonNum = []

with open('FirstGenPokemon.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        PokemonNum.append(Pokemon(row[1], row[2], row[3], row[4], row[5], row[6], row[7], row[8]))
PokemonNum[1].Type1
# Out:
# 'grass'

# %%
print('Enter Pokemon 1 Name')
Pokemon1 = input()
Input1 = Pokemon1
Count = 0
while Input1 == Pokemon1:
    for x in range(1,151):
        if Pokemon1 == PokemonNum[x].Name:
            Pokemon1 = PokemonNum[x]
        else:
            Count += 1
    if Count == 151:
        print('Pokemon not found. Please enter new Pokemon.')
        Pokemon1 = input()
        Input1 = Pokemon1
# Out:
# Enter Pokemon 1 Name
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/sw/gsf2knms2977tk_sh9wq1p580000gn/T/ipykernel_72322/2294574034.py in <module>
#       5 while Input1 == Pokemon1:
#       6     for x in range(1,151):
# ----> 7         if Pokemon1 == PokemonNum[x].Name:
#       8             Pokemon1 = PokemonNum[x]
#       9         else:
#
# KeyboardInterrupt:

# %%
x = input()
print(x)
